# %% [markdown]
# <a href="https://colab.research.google.com/github/arjunkrishnasr/social-network-analytics-lab-digital-assessment2/blob/main/Fast_Greedy_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fast Greedy Algorithm for Community Detection**
#
# **Arjun Krishna S R**
#
# **22MCB0038**

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
def fast_greedy(G):
    communities_generator = nx.algorithms.community.greedy_modularity_communities(G)
    communities = [list(comm) for comm in communities_generator]
    return communities

# %%
# Create a random graph for demonstration
G = nx.erdos_renyi_graph(n=50, p=0.1)

# %%
# Perform community detection using Fast Greedy algorithm
detected_communities = fast_greedy(G)

# %%
# Visualize the graph and detected communities
pos = nx.spring_layout(G, seed=42)

# %%
# Draw the graph
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', width=0.5)

# %%
# Draw the detected communities
colors = ['red', 'blue', 'green', 'orange', 'purple']
for i, community in enumerate(detected_communities):
    nx.draw_networkx_nodes(G, pos, nodelist=community, node_color=colors[i % len(colors)], alpha=0.7)

# Display the plot
plt.show()
